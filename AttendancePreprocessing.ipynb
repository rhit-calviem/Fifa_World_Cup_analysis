# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('merged.csv')
df1.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral game_winner penalty_winner first_shooter  Shootout team  \
# 0  Scotland    False         TIE            NaN           NaN     False  NaN
# 1   England    False     England            NaN           NaN     False  NaN
# 2  Scotland    False    Scotland            NaN           NaN     False  NaN
# 3   England    False         TIE            NaN           NaN     False  NaN
# 4  Scotland    False    Scotland            NaN           NaN     False  NaN
#
#   scorer  minute own_goal penalty
# ...

# %%
df1['tournament'].value_counts()
# Out:
# tournament
# FIFA World Cup qualification        23505
# Friendly                            17773
# UEFA Euro qualification              8152
# FIFA World Cup                       2798
# Copa América                         2733
#                                     ...
# The Other Final                         1
# Copa Confraternidad                     1
# Évence Coppée Trophy                    1
# Real Madrid 75th Anniversary Cup        1
# FIFA 75th Anniversary Cup               1
# Name: count, Length: 147, dtype: int64

# %%
df2 = pd.read_excel('C:/Users/calviem/OneDrive - Rose-Hulman Institute of Technology/Desktop/School/Winter Quarter Year 2/MA 384/Project/WorldCupAttendance1930_2018.xlsx',skiprows = 4)
df2.head(20)
# Out:
#     Unnamed: 0                Unnamed: 1  Total attendance  \
# 0          NaN               2022 Quatar           3404252
# 1          NaN               2018 Russia           3031768
# 2          NaN               2014 Brazil           3441450
# 3          NaN         2010 South Africa           3167984
# 4          NaN              2006 Germany           3367000
# 5          NaN  2002 Japan / South Korea           2724604
# 6          NaN               1998 France           2859234
# 7          NaN                  1994 USA           3568567
# 8          NaN                1990 Italy           2527348
# 9          NaN               1986 Mexico           2407431
# 10         NaN                1982 Spain           1856277
# 11         NaN            1978 Argentina           1610215
# 12         NaN              1974 Germany           1774022
# 13         NaN               1970 Mexico           1673975
# 14         NaN              1966 England           1614677
# ...

# %%
df2 = df2.drop(df2.columns[0], axis = 1)
df2.head(20)
# Out:
#                   Unnamed: 1  Total attendance  Average attendance per game
# 0                2022 Quatar           3404252                        53191
# 1                2018 Russia           3031768                        47371
# 2                2014 Brazil           3441450                        53772
# 3          2010 South Africa           3167984                        49499
# 4               2006 Germany           3367000                        52609
# 5   2002 Japan / South Korea           2724604                        42571
# 6                1998 France           2859234                        44676
# 7                   1994 USA           3568567                        68626
# 8                 1990 Italy           2527348                        48411
# 9                1986 Mexico           2407431                        46297
# 10                1982 Spain           1856277                        35698
# ...

# %%
df2.rename(columns = {'Unnamed: 1':'country'},inplace = True)
df2.head(20)
# Out:
#                      country  Total attendance  Average attendance per game
# 0                2022 Quatar           3404252                        53191
# 1                2018 Russia           3031768                        47371
# 2                2014 Brazil           3441450                        53772
# 3          2010 South Africa           3167984                        49499
# 4               2006 Germany           3367000                        52609
# 5   2002 Japan / South Korea           2724604                        42571
# 6                1998 France           2859234                        44676
# 7                   1994 USA           3568567                        68626
# 8                 1990 Italy           2527348                        48411
# 9                1986 Mexico           2407431                        46297
# 10                1982 Spain           1856277                        35698
# ...

# %%
df2[['year','country']] = df2['country'].str.extract(r'(\d+)\s(.*)')
df2.head(20)
# Out:
#                 country  Total attendance  Average attendance per game  year
# 0                Quatar           3404252                        53191  2022
# 1                Russia           3031768                        47371  2018
# 2                Brazil           3441450                        53772  2014
# 3          South Africa           3167984                        49499  2010
# 4               Germany           3367000                        52609  2006
# 5   Japan / South Korea           2724604                        42571  2002
# 6                France           2859234                        44676  1998
# 7                   USA           3568567                        68626  1994
# 8                 Italy           2527348                        48411  1990
# 9                Mexico           2407431                        46297  1986
# 10                Spain           1856277                        35698  1982
# ...

# %%
df2['country'] = df2['country'].str.replace('USA','United States')
df2.head(20)
# Out:
#                 country  Total attendance  Average attendance per game  year
# 0                Quatar           3404252                        53191  2022
# 1                Russia           3031768                        47371  2018
# 2                Brazil           3441450                        53772  2014
# 3          South Africa           3167984                        49499  2010
# 4               Germany           3367000                        52609  2006
# 5   Japan / South Korea           2724604                        42571  2002
# 6                France           2859234                        44676  1998
# 7         United States           3568567                        68626  1994
# 8                 Italy           2527348                        48411  1990
# 9                Mexico           2407431                        46297  1986
# 10                Spain           1856277                        35698  1982
# ...
